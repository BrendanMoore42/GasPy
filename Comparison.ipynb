# %%
import re
import json
import pickle
import requests
import pandas as pd
from ast import literal_eval
from bs4 import BeautifulSoup
from datetime import datetime, timedelta

# %%
# with open('Data/master_data.json', 'r') as f:
#     data_dfs = json.load(f)

# %%
pd.DataFrame(data_dfs['Ancaster'][0])
# Out:
#                                    Address      City  \
# 0       100 Legend Ct near Martindale Cr    Ancaster
# 1         1180 Wilson St W & Garner Rd W    Ancaster
# 2   1136 Golf Links Rd & Stone Church Rd    Ancaster
# 3           10 Legend Ct & Golf Links Rd    Ancaster
# 4      523 Garner Rd E near Southcote Rd    Ancaster
# 5  33 Wilson St W near Fiddlers Green Rd    Ancaster
# 6     16 Wilson St W & Fiddlers Green Rd    Ancaster
#
#                          Date Prices        Station
# 0  2019-08-03 11:27:39.538768  111.4        Costco
# 1  2019-08-03 10:17:39.538768  117.6       Pioneer
# 2  2019-08-03 11:17:39.538768  119.9          Esso
# 3  2019-08-03 09:17:39.538768  119.9         Shell
# 4  2019-08-03 12:14:39.538768  120.9          Esso
# 5  2019-08-03 10:17:39.539767  122.9          Esso
# 6  2019-08-02 12:17:39.539767  123.3  Petro-Canada

# %%
pd.DataFrame(data_dfs['Ancaster'][1])
# Out:
#                                    Address      City  \
# 0       100 Legend Ct near Martindale Cr    Ancaster
# 1         1180 Wilson St W & Garner Rd W    Ancaster
# 2   1136 Golf Links Rd & Stone Church Rd    Ancaster
# 3           10 Legend Ct & Golf Links Rd    Ancaster
# 4      523 Garner Rd E near Southcote Rd    Ancaster
# 5  33 Wilson St W near Fiddlers Green Rd    Ancaster
# 6     16 Wilson St W & Fiddlers Green Rd    Ancaster
#
#                          Date Prices        Station
# 0  2019-08-03 11:26:57.869366  111.4        Costco
# 1  2019-08-03 10:21:57.870365  117.6       Pioneer
# 2  2019-08-03 12:20:57.870365  119.9          Esso
# 3  2019-08-03 09:21:57.870365  119.9         Shell
# 4  2019-08-03 12:13:57.870365  120.9          Esso
# 5  2019-08-03 10:21:57.871364  122.9          Esso
# 6  2019-08-02 12:21:57.871364  123.3  Petro-Canada

# %%
len(data_dfs['Ancaster'])
# Out:
# 2
